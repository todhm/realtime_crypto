# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import json
from datetime import datetime
import numpy as np
from fbprophet import Prophet
import pickle
import math

# %% [markdown]
# # Read Bitstamp Data

# %% [markdown]
# First, let's read in the data from Kaggle.

# %%
df = pd.read_csv('bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2019-03-13.csv')

# %%
df.tail()
# Out:
#           Timestamp     Open     High      Low    Close  Volume_(BTC)  \
# 3778812  1552434960      NaN      NaN      NaN      NaN           NaN
# 3778813  1552435020      NaN      NaN      NaN      NaN           NaN
# 3778814  1552435080  3860.09  3861.05  3860.09  3861.05      0.378637
# 3778815  1552435140  3860.18  3860.18  3859.74  3859.74      1.056403
# 3778816  1552435200  3861.37  3862.01  3861.37  3861.95      0.198124
#
#          Volume_(Currency)  Weighted_Price
# 3778812                NaN             NaN
# 3778813                NaN             NaN
# 3778814        1461.770077     3860.606378
# 3778815        4077.863045     3860.139080
# 3778816         765.149137     3861.967464

# %%
df['ds'] = df['Timestamp'].apply(lambda x: datetime.fromtimestamp(x))
df = df.set_index(df['ds'])

# %% [markdown]
# # Train Model Using Prophet

# %% [markdown]
# Next, let's take the log of weighted price and train our model using that feature.

# %%
df['y'] = np.log(df['Weighted_Price'])

# %%
df_subset = df[df['ds'] >= pd.Timestamp('2016-01-01')]

# %%
m = Prophet()

# %%
# %time m.fit(df_subset[['ds','y']]);
# Out:
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# CPU times: user 1h 23min 40s, sys: 4min 24s, total: 1h 28min 5s
# Wall time: 1h 47min 25s

# %% [markdown]
# Only run the below if you want to save a **NEW** model

# %%
with open('btc_model.pickle', 'wb') as pickle_file:
    pickle.dump(m, pickle_file)
    pickle_file.close()

# %% [markdown]
# Use this if you've already trained the model

# %%
with open('btc_model.pickle', 'rb') as pickle_file:
    m = pickle.Unpickler(pickle_file)
    m = m.load()

# %% [markdown]
# # Generate Prediction

# %% [markdown]
# Now, let's predict out prices using the model we just trained.

# %%
future = m.make_future_dataframe(periods=150000, freq='1min', include_history=False)
future.tail()
# Out:
#                         ds
# 149995 2019-06-25 12:56:00
# 149996 2019-06-25 12:57:00
# 149997 2019-06-25 12:58:00
# 149998 2019-06-25 12:59:00
# 149999 2019-06-25 13:00:00

# %%
# %time fcst = m.predict(future)
# Out:
# /usr/local/lib/python3.7/site-packages/fbprophet/forecaster.py:1008: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   X = seasonal_features.as_matrix()
# /usr/local/lib/python3.7/site-packages/fbprophet/forecaster.py:1132: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   seasonal = np.matmul(seasonal_features.as_matrix(), beta) * self.y_scale
# CPU times: user 6min 11s, sys: 51.3 s, total: 7min 2s
# Wall time: 4min 48s

# %%
fcst
# Out:
#                         ds     trend  yhat_lower  yhat_upper  trend_lower  \
# 0      2019-03-13 09:01:00  8.212589    8.159309    8.347651     8.212589
# 1      2019-03-13 09:02:00  8.212587    8.158974    8.340794     8.212587
# 2      2019-03-13 09:03:00  8.212585    8.160254    8.349577     8.212585
# 3      2019-03-13 09:04:00  8.212583    8.159727    8.346778     8.212583
# 4      2019-03-13 09:05:00  8.212580    8.159819    8.342412     8.212580
# 5      2019-03-13 09:06:00  8.212578    8.166877    8.344831     8.212578
# 6      2019-03-13 09:07:00  8.212576    8.160349    8.347643     8.212576
# 7      2019-03-13 09:08:00  8.212574    8.165809    8.340966     8.212574
# 8      2019-03-13 09:09:00  8.212572    8.156169    8.351815     8.212572
# 9      2019-03-13 09:10:00  8.212569    8.164032    8.345849     8.212569
# 10     2019-03-13 09:11:00  8.212567    8.162834    8.347374     8.212567
# 11     2019-03-13 09:12:00  8.212565    8.163219    8.349145     8.212565
# 12     2019-03-13 09:13:00  8.212563    8.156233    8.350416     8.212563
# 13     2019-03-13 09:14:00  8.212561    8.161309    8.347137     8.212561
# 14     2019-03-13 09:15:00  8.212559    8.158269    8.341133     8.212559
# 15     2019-03-13 09:16:00  8.212556    8.156912    8.345751     8.212556
# 16     2019-03-13 09:17:00  8.212554    8.162964    8.346594     8.212554
# 17     2019-03-13 09:18:00  8.212552    8.158931    8.345662     8.212552
# 18     2019-03-13 09:19:00  8.212550    8.164756    8.341303     8.212550
# 19     2019-03-13 09:20:00  8.212548    8.158949    8.348068     8.212548
# 20     2019-03-13 09:21:00  8.212546    8.157309    8.342671     8.212546
# 21     2019-03-13 09:22:00  8.212543    8.163121    8.347495     8.212543
# 22     2019-03-13 09:23:00  8.212541    8.167567    8.345501     8.212541
# 23     2019-03-13 09:24:00  8.212539    8.162509    8.348917     8.212539
# 24     2019-03-13 09:25:00  8.212537    8.161365    8.346316     8.212537
# 25     2019-03-13 09:26:00  8.212535    8.161990    8.346753     8.212535
# 26     2019-03-13 09:27:00  8.212533    8.167008    8.337770     8.212533
# 27     2019-03-13 09:28:00  8.212530    8.157736    8.349168     8.212530
# 28     2019-03-13 09:29:00  8.212528    8.158018    8.348833     8.212528
# 29     2019-03-13 09:30:00  8.212526    8.161167    8.346203     8.212526
# ...                    ...       ...         ...         ...          ...
# 149970 2019-06-25 12:31:00  7.886782    6.144073    9.949834     5.970728
# 149971 2019-06-25 12:32:00  7.886780    6.134576    9.919905     5.970720
# 149972 2019-06-25 12:33:00  7.886778    6.129207    9.980252     5.970712
# 149973 2019-06-25 12:34:00  7.886775    6.092030    9.955085     5.970704
# 149974 2019-06-25 12:35:00  7.886773    6.077650    9.947598     5.970696
# 149975 2019-06-25 12:36:00  7.886771    6.066665    9.949936     5.970688
# 149976 2019-06-25 12:37:00  7.886769    6.096482    9.939289     5.970680
# 149977 2019-06-25 12:38:00  7.886767    6.092701    9.920044     5.970672
# 149978 2019-06-25 12:39:00  7.886764    6.110085    9.933835     5.970664
# 149979 2019-06-25 12:40:00  7.886762    6.117072    9.952950     5.970656
# 149980 2019-06-25 12:41:00  7.886760    6.076709    9.937529     5.970649
# 149981 2019-06-25 12:42:00  7.886758    6.087718    9.922616     5.970641
# 149982 2019-06-25 12:43:00  7.886756    6.109975    9.979570     5.970633
# 149983 2019-06-25 12:44:00  7.886754    6.099724    9.962761     5.970625
# 149984 2019-06-25 12:45:00  7.886751    6.080301    9.966093     5.970617
# 149985 2019-06-25 12:46:00  7.886749    6.135211    9.953666     5.970609
# 149986 2019-06-25 12:47:00  7.886747    6.065274    9.957853     5.970601
# 149987 2019-06-25 12:48:00  7.886745    6.119946    9.974924     5.970593
# 149988 2019-06-25 12:49:00  7.886743    6.086846    9.925765     5.970585
# 149989 2019-06-25 12:50:00  7.886741    6.087658    9.960656     5.970577
# 149990 2019-06-25 12:51:00  7.886738    6.101609    9.975050     5.970569
# 149991 2019-06-25 12:52:00  7.886736    6.064115    9.978713     5.970561
# 149992 2019-06-25 12:53:00  7.886734    6.101531    9.983355     5.970553
# 149993 2019-06-25 12:54:00  7.886732    6.128345    9.976941     5.970545
# 149994 2019-06-25 12:55:00  7.886730    6.100784    9.915305     5.970537
# 149995 2019-06-25 12:56:00  7.886728    6.087229    9.912285     5.970529
# 149996 2019-06-25 12:57:00  7.886725    6.094385    9.932846     5.970521
# 149997 2019-06-25 12:58:00  7.886723    6.120723    9.917709     5.970513
# 149998 2019-06-25 12:59:00  7.886721    6.113494    9.971113     5.970505
# 149999 2019-06-25 13:00:00  7.886719    6.087926    9.979429     5.970497
#
#         trend_upper     daily  daily_lower  daily_upper  seasonal    ...     \
# 0          8.212589  0.000226     0.000226     0.000226  0.040386    ...
# 1          8.212587  0.000228     0.000228     0.000228  0.040386    ...
# 2          8.212585  0.000230     0.000230     0.000230  0.040385    ...
# 3          8.212583  0.000231     0.000231     0.000231  0.040384    ...
# 4          8.212580  0.000233     0.000233     0.000233  0.040384    ...
# 5          8.212578  0.000235     0.000235     0.000235  0.040383    ...
# 6          8.212576  0.000236     0.000236     0.000236  0.040382    ...
# 7          8.212574  0.000238     0.000238     0.000238  0.040381    ...
# 8          8.212572  0.000239     0.000239     0.000239  0.040380    ...
# 9          8.212569  0.000240     0.000240     0.000240  0.040380    ...
# 10         8.212567  0.000242     0.000242     0.000242  0.040378    ...
# 11         8.212565  0.000243     0.000243     0.000243  0.040377    ...
# 12         8.212563  0.000244     0.000244     0.000244  0.040376    ...
# 13         8.212561  0.000245     0.000245     0.000245  0.040375    ...
# 14         8.212559  0.000246     0.000246     0.000246  0.040374    ...
# 15         8.212556  0.000247     0.000247     0.000247  0.040372    ...
# 16         8.212554  0.000248     0.000248     0.000248  0.040371    ...
# 17         8.212552  0.000249     0.000249     0.000249  0.040370    ...
# 18         8.212550  0.000250     0.000250     0.000250  0.040368    ...
# 19         8.212548  0.000251     0.000251     0.000251  0.040367    ...
# 20         8.212546  0.000251     0.000251     0.000251  0.040365    ...
# 21         8.212543  0.000252     0.000252     0.000252  0.040363    ...
# 22         8.212541  0.000252     0.000252     0.000252  0.040361    ...
# 23         8.212539  0.000253     0.000253     0.000253  0.040360    ...
# 24         8.212537  0.000253     0.000253     0.000253  0.040358    ...
# 25         8.212535  0.000254     0.000254     0.000254  0.040356    ...
# 26         8.212533  0.000254     0.000254     0.000254  0.040354    ...
# 27         8.212530  0.000254     0.000254     0.000254  0.040352    ...
# 28         8.212528  0.000254     0.000254     0.000254  0.040350    ...
# 29         8.212526  0.000255     0.000255     0.000255  0.040347    ...
# ...             ...       ...          ...          ...       ...    ...
# 149970     9.826891 -0.000510    -0.000510    -0.000510  0.135578    ...
# 149971     9.826905 -0.000515    -0.000515    -0.000515  0.135572    ...
# 149972     9.826918 -0.000519    -0.000519    -0.000519  0.135566    ...
# 149973     9.826932 -0.000524    -0.000524    -0.000524  0.135560    ...
# 149974     9.826946 -0.000528    -0.000528    -0.000528  0.135554    ...
# 149975     9.826960 -0.000532    -0.000532    -0.000532  0.135548    ...
# 149976     9.826973 -0.000537    -0.000537    -0.000537  0.135542    ...
# 149977     9.826987 -0.000541    -0.000541    -0.000541  0.135536    ...
# 149978     9.827001 -0.000545    -0.000545    -0.000545  0.135530    ...
# 149979     9.827015 -0.000549    -0.000549    -0.000549  0.135524    ...
# 149980     9.827028 -0.000553    -0.000553    -0.000553  0.135519    ...
# 149981     9.827042 -0.000557    -0.000557    -0.000557  0.135513    ...
# 149982     9.827056 -0.000561    -0.000561    -0.000561  0.135507    ...
# 149983     9.827069 -0.000565    -0.000565    -0.000565  0.135502    ...
# 149984     9.827083 -0.000569    -0.000569    -0.000569  0.135496    ...
# 149985     9.827097 -0.000573    -0.000573    -0.000573  0.135491    ...
# 149986     9.827111 -0.000577    -0.000577    -0.000577  0.135485    ...
# 149987     9.827124 -0.000580    -0.000580    -0.000580  0.135480    ...
# 149988     9.827138 -0.000584    -0.000584    -0.000584  0.135475    ...
# 149989     9.827152 -0.000588    -0.000588    -0.000588  0.135469    ...
# 149990     9.827166 -0.000591    -0.000591    -0.000591  0.135464    ...
# 149991     9.827179 -0.000595    -0.000595    -0.000595  0.135459    ...
# 149992     9.827193 -0.000598    -0.000598    -0.000598  0.135454    ...
# 149993     9.827207 -0.000601    -0.000601    -0.000601  0.135449    ...
# 149994     9.827221 -0.000604    -0.000604    -0.000604  0.135444    ...
# 149995     9.827234 -0.000608    -0.000608    -0.000608  0.135439    ...
# 149996     9.827248 -0.000611    -0.000611    -0.000611  0.135434    ...
# 149997     9.827262 -0.000614    -0.000614    -0.000614  0.135430    ...
# 149998     9.827276 -0.000617    -0.000617    -0.000617  0.135425    ...
# 149999     9.827289 -0.000620    -0.000620    -0.000620  0.135420    ...
#
#         seasonalities  seasonalities_lower  seasonalities_upper    weekly  \
# 0            0.040386             0.040386             0.040386  0.000630
# 1            0.040386             0.040386             0.040386  0.000629
# 2            0.040385             0.040385             0.040385  0.000629
# 3            0.040384             0.040384             0.040384  0.000628
# 4            0.040384             0.040384             0.040384  0.000628
# 5            0.040383             0.040383             0.040383  0.000627
# 6            0.040382             0.040382             0.040382  0.000627
# 7            0.040381             0.040381             0.040381  0.000627
# 8            0.040380             0.040380             0.040380  0.000626
# 9            0.040380             0.040380             0.040380  0.000626
# 10           0.040378             0.040378             0.040378  0.000625
# 11           0.040377             0.040377             0.040377  0.000625
# 12           0.040376             0.040376             0.040376  0.000625
# 13           0.040375             0.040375             0.040375  0.000624
# 14           0.040374             0.040374             0.040374  0.000624
# 15           0.040372             0.040372             0.040372  0.000623
# 16           0.040371             0.040371             0.040371  0.000623
# 17           0.040370             0.040370             0.040370  0.000623
# 18           0.040368             0.040368             0.040368  0.000622
# 19           0.040367             0.040367             0.040367  0.000622
# 20           0.040365             0.040365             0.040365  0.000621
# 21           0.040363             0.040363             0.040363  0.000621
# 22           0.040361             0.040361             0.040361  0.000621
# 23           0.040360             0.040360             0.040360  0.000620
# 24           0.040358             0.040358             0.040358  0.000620
# 25           0.040356             0.040356             0.040356  0.000619
# 26           0.040354             0.040354             0.040354  0.000619
# 27           0.040352             0.040352             0.040352  0.000619
# 28           0.040350             0.040350             0.040350  0.000618
# 29           0.040347             0.040347             0.040347  0.000618
# ...               ...                  ...                  ...       ...
# 149970       0.135578             0.135578             0.135578  0.001625
# 149971       0.135572             0.135572             0.135572  0.001625
# 149972       0.135566             0.135566             0.135566  0.001625
# 149973       0.135560             0.135560             0.135560  0.001624
# 149974       0.135554             0.135554             0.135554  0.001624
# 149975       0.135548             0.135548             0.135548  0.001624
# 149976       0.135542             0.135542             0.135542  0.001624
# 149977       0.135536             0.135536             0.135536  0.001623
# 149978       0.135530             0.135530             0.135530  0.001623
# 149979       0.135524             0.135524             0.135524  0.001623
# 149980       0.135519             0.135519             0.135519  0.001623
# 149981       0.135513             0.135513             0.135513  0.001623
# 149982       0.135507             0.135507             0.135507  0.001622
# 149983       0.135502             0.135502             0.135502  0.001622
# 149984       0.135496             0.135496             0.135496  0.001622
# 149985       0.135491             0.135491             0.135491  0.001622
# 149986       0.135485             0.135485             0.135485  0.001621
# 149987       0.135480             0.135480             0.135480  0.001621
# 149988       0.135475             0.135475             0.135475  0.001621
# 149989       0.135469             0.135469             0.135469  0.001621
# 149990       0.135464             0.135464             0.135464  0.001620
# 149991       0.135459             0.135459             0.135459  0.001620
# 149992       0.135454             0.135454             0.135454  0.001620
# 149993       0.135449             0.135449             0.135449  0.001620
# 149994       0.135444             0.135444             0.135444  0.001619
# 149995       0.135439             0.135439             0.135439  0.001619
# 149996       0.135434             0.135434             0.135434  0.001619
# 149997       0.135430             0.135430             0.135430  0.001619
# 149998       0.135425             0.135425             0.135425  0.001618
# 149999       0.135420             0.135420             0.135420  0.001618
#
#         weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 0           0.000630      0.000630  0.039531      0.039531      0.039531
# 1           0.000629      0.000629  0.039529      0.039529      0.039529
# 2           0.000629      0.000629  0.039527      0.039527      0.039527
# 3           0.000628      0.000628  0.039525      0.039525      0.039525
# 4           0.000628      0.000628  0.039523      0.039523      0.039523
# 5           0.000627      0.000627  0.039521      0.039521      0.039521
# 6           0.000627      0.000627  0.039519      0.039519      0.039519
# 7           0.000627      0.000627  0.039517      0.039517      0.039517
# 8           0.000626      0.000626  0.039515      0.039515      0.039515
# 9           0.000626      0.000626  0.039513      0.039513      0.039513
# 10          0.000625      0.000625  0.039511      0.039511      0.039511
# 11          0.000625      0.000625  0.039510      0.039510      0.039510
# 12          0.000625      0.000625  0.039508      0.039508      0.039508
# 13          0.000624      0.000624  0.039506      0.039506      0.039506
# 14          0.000624      0.000624  0.039504      0.039504      0.039504
# 15          0.000623      0.000623  0.039502      0.039502      0.039502
# 16          0.000623      0.000623  0.039500      0.039500      0.039500
# 17          0.000623      0.000623  0.039498      0.039498      0.039498
# 18          0.000622      0.000622  0.039496      0.039496      0.039496
# 19          0.000622      0.000622  0.039494      0.039494      0.039494
# 20          0.000621      0.000621  0.039492      0.039492      0.039492
# 21          0.000621      0.000621  0.039490      0.039490      0.039490
# 22          0.000621      0.000621  0.039488      0.039488      0.039488
# 23          0.000620      0.000620  0.039486      0.039486      0.039486
# 24          0.000620      0.000620  0.039485      0.039485      0.039485
# 25          0.000619      0.000619  0.039483      0.039483      0.039483
# 26          0.000619      0.000619  0.039481      0.039481      0.039481
# 27          0.000619      0.000619  0.039479      0.039479      0.039479
# 28          0.000618      0.000618  0.039477      0.039477      0.039477
# 29          0.000618      0.000618  0.039475      0.039475      0.039475
# ...              ...           ...       ...           ...           ...
# 149970      0.001625      0.001625  0.134463      0.134463      0.134463
# 149971      0.001625      0.001625  0.134462      0.134462      0.134462
# 149972      0.001625      0.001625  0.134461      0.134461      0.134461
# 149973      0.001624      0.001624  0.134459      0.134459      0.134459
# 149974      0.001624      0.001624  0.134458      0.134458      0.134458
# 149975      0.001624      0.001624  0.134456      0.134456      0.134456
# 149976      0.001624      0.001624  0.134455      0.134455      0.134455
# 149977      0.001623      0.001623  0.134453      0.134453      0.134453
# 149978      0.001623      0.001623  0.134452      0.134452      0.134452
# 149979      0.001623      0.001623  0.134451      0.134451      0.134451
# 149980      0.001623      0.001623  0.134449      0.134449      0.134449
# 149981      0.001623      0.001623  0.134448      0.134448      0.134448
# 149982      0.001622      0.001622  0.134446      0.134446      0.134446
# 149983      0.001622      0.001622  0.134445      0.134445      0.134445
# 149984      0.001622      0.001622  0.134443      0.134443      0.134443
# 149985      0.001622      0.001622  0.134442      0.134442      0.134442
# 149986      0.001621      0.001621  0.134441      0.134441      0.134441
# 149987      0.001621      0.001621  0.134439      0.134439      0.134439
# 149988      0.001621      0.001621  0.134438      0.134438      0.134438
# 149989      0.001621      0.001621  0.134436      0.134436      0.134436
# 149990      0.001620      0.001620  0.134435      0.134435      0.134435
# 149991      0.001620      0.001620  0.134433      0.134433      0.134433
# 149992      0.001620      0.001620  0.134432      0.134432      0.134432
# 149993      0.001620      0.001620  0.134431      0.134431      0.134431
# 149994      0.001619      0.001619  0.134429      0.134429      0.134429
# 149995      0.001619      0.001619  0.134428      0.134428      0.134428
# 149996      0.001619      0.001619  0.134426      0.134426      0.134426
# 149997      0.001619      0.001619  0.134425      0.134425      0.134425
# 149998      0.001618      0.001618  0.134423      0.134423      0.134423
# 149999      0.001618      0.001618  0.134422      0.134422      0.134422
#
#             yhat
# 0       8.252975
# 1       8.252973
# 2       8.252970
# 3       8.252967
# 4       8.252964
# 5       8.252961
# 6       8.252958
# 7       8.252955
# 8       8.252952
# 9       8.252949
# 10      8.252946
# 11      8.252943
# 12      8.252939
# 13      8.252936
# 14      8.252932
# 15      8.252929
# 16      8.252925
# 17      8.252922
# 18      8.252918
# 19      8.252914
# 20      8.252911
# 21      8.252907
# 22      8.252903
# 23      8.252899
# 24      8.252895
# 25      8.252891
# 26      8.252886
# 27      8.252882
# 28      8.252878
# 29      8.252873
# ...          ...
# 149970  8.022360
# 149971  8.022352
# 149972  8.022343
# 149973  8.022335
# 149974  8.022327
# 149975  8.022319
# 149976  8.022311
# 149977  8.022303
# 149978  8.022295
# 149979  8.022287
# 149980  8.022279
# 149981  8.022271
# 149982  8.022263
# 149983  8.022255
# 149984  8.022248
# 149985  8.022240
# 149986  8.022232
# 149987  8.022225
# 149988  8.022217
# 149989  8.022210
# 149990  8.022203
# 149991  8.022195
# 149992  8.022188
# 149993  8.022181
# 149994  8.022174
# 149995  8.022167
# 149996  8.022160
# 149997  8.022153
# 149998  8.022146
# 149999  8.022139
#
# [150000 rows x 22 columns]

# %% [markdown]
# We can use our forecast (`fcst`) to plot the prediction we just made:

# %%
m.plot(fcst);

# %% [markdown]
# Now let's convert our `log(price)` back to price and calculate whether the minute is a buy or sell minute

# %%
fcst['yhat_exp'] = fcst['yhat'].apply(lambda x: math.exp(x))

# %%
output = fcst[fcst['ds'] > '2018-01-01'][['ds','yhat_exp']]

# %%
output['delta'] = output.yhat_exp.diff()

# %%
output = output[output['ds'] > '2017-12-25']

# %%
def choose_side(x):
    if x > 0:
        return 'buy'
    else: 
        return 'sell'

# %%
output['side'] = output['delta'].apply(lambda x: choose_side(x))

# %% [markdown]
# We can count the number of buy vs. sell minutes with:

# %%
output.groupby('side')['ds'].count()
# Out:
# side
# buy      48973
# sell    101027
# Name: ds, dtype: int64

# %% [markdown]
# # Store Output

# %% [markdown]
# Save file to CSV

# %%
output[['ds','side']].to_csv('2018_full_trade_forecast.csv', index=False)

# %% [markdown]
# # Analyze Output

# %% [markdown]
# Generate a components plot

# %%
fcst_sampled = fcst[fcst['ds'] > '2018-01-01 00:00:00']

# %%
a = m.plot_components(fcst_sampled)

# %% [markdown]
# You can save the components plot to a file if you'd like

# %%
a.savefig('components_plot.png', dpi=200)
